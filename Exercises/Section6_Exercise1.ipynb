# %% [markdown]
# ## Create a story with ArcGIS StoryMaps

# %% [markdown]
# https://arcg.is/1GnHjf0

# %% [markdown]
# ### Introduction
# An important step in spatial data science is communicating the results of your analysis. ArcGIS StoryMaps is one of the most powerful tools that you can use to share information and engage decision makers. It integrates text, images, maps, and other multimedia to help you visualize your story.
# But how do you tell a good story? In this exercise, you will see a two-phase approach for effective storytelling. The first is preparation, where the focus is on identifying an audience and then using an outline to convey key takeaways and organize content. The second phase is the creation process, where you will use the story builder to create a story based on the outline from the preparation phase and learn how to translate information into a compelling story that uses text, images, and maps.
#
# ### Scenario
# An effective way to learn to tell better stories is to copy elements that you enjoy from other storytellers. You will create a story from the elements of a previously published story, which documented the experiences of three National Geographic explorers who visited Guatemala. The purpose of their expedition was to learn more about the coexistence of volcanoes and communities. You will use this example to identify the characteristics of a good story and to learn how to use the story builder in ArcGIS StoryMaps.
#
# For more information about ArcGIS StoryMaps, go to [ArcGIS StoryMaps Overview](https://www.esri.com/en-us/arcgis/products/arcgis-storymaps/overview).

# %% [markdown]
# ### **Identify the audience**

# %% [markdown]
# The first step to crafting a compelling story is to start with an outline based on your audience. By working through foundational questions focused on your audience — what you want them to learn, how you can connect with them most effectively — you will not only save time later in the story creation phase, but also increase your likelihood of crafting something that resonates with them.
#
# In this step, you will review an existing story. By reviewing it, you will identify the target audience and define the key takeaways that are outlined in the story.
#
# In a new web browser tab, open the story titled `In the Shadow of a Volcano` (https://storymaps.arcgis.com/stories/0af82ec0fe7f4421b3fe4bd72cfe2c73Opens in new window).
#
# The story is about three National Geographic explorers who visited an active Guatemalan volcano to conduct research.
#
# Read the story and answer the following questions.
#
# > Q. Who do you think is the target audience for this story?\
# > A. The target audience could be anyone interested in what life is like living near an active volcano.
#
# Notice how the intended audience has an impact on the story's tone, vocabulary, emotional arc, and permissible level of detail.
#
# Key takeaways are defined with the audience of the story in mind by determining what is the most important message they will remember, even if they recall only one or two things about the story. It is best practice to write down these key points for easy reference and to use them as a guide while you outline your story.
#
# >Q. What is a key takeaway for this story?\
#
# >A. Answers to this question will vary but can include the following takeaway: The story details the course of their expedition and the importance of the research that they conducted to help keep communities near active volcanoes safe.
#
# Working through these foundational questions to define your audience and key takeaways will help you prepare an outline for an interesting and relevant story. The next step is to create an inventory of some of the content that you will include in your story.

# %% [markdown]
# ### **Create the content inventory**

# %% [markdown]
# Before creating your story, it is a best practice to gather the materials that you will use to tell the story. The text and graphics for this story have been organized and made available for you to download.
#
# In this step, you will create the content inventory.
#
# 1. Open a new web browser tab or window.
#
# 2. Go to https://links.esri.com/Section06/DataOpens in new window and download the exercise data ZIP file.
#
# >Note: The complete URL to the exercise data file is https://www.arcgis.com/home/item.html?id=c7718e1003e84bb7ba0af3d33e8cdf82Opens in new window.
#
# 3. Extract the files to the EsriTraining folder on your local computer.
#
# 4. In File Explorer, open the StoryMaps folder.
#
# The StoryMaps folder includes documents with the text that you will include in your story and a StoryMapsImages folder with image files for your story.

# %% [markdown]
# ### **Organize content using an outline**

# %% [markdown]
# The final step before creating a story is using an outline to organize the text and media in your content inventory. Various outline formats can be used, including a simple bulleted list, a slide deck, or even a collection of index cards that you organize on your desk. The exact format is not important—what matters most is that you choose a format that works for you.
#
# In this step, you will review an outline in preparation for creating a version of the In the Shadow of the Volcano story.
#
# 1. In File Explorer, from the StoryMaps folder, open either StoryMapsText.pdf or StoryMapsText.docx.
#
# ![text.JPG](attachment:6acc1817-61e7-498b-991a-e5872e591a9f.JPG)
#
# >Note: These documents are the same but are provided in two different file formats.
#
# 2. From the StoryMaps folder, open either StoryMapsOutline.pdf or StoryMapsOutline.docx.
#
# ![outline.JPG](attachment:2314b083-1214-48a1-a9b2-7da226000234.JPG)
#
# 3. Review the StoryMapsOutline document and compare it with the StoryMapsText document.
#
# This outline document shows the structure that was used to create the example story in ArcGIS StoryMaps. The outline includes the following types of details:
#
# - `Who`: Establishes who is venturing out into the world and explains why they embarked on this journey
# - `Where`: Locates the place or places traveled and re-creates the feeling of being there for the reader
# - `When`: Clearly communicates the chronological order of the events that occurred on the expedition, even if the story does not follow a linear timeline
# - `What`: Includes elements that evoke tension or uncertainty in the reader's mind, keeping the reader invested in finding out what happens next
# - `Why`: Explains the key takeaways from the expedition when it has ended, helping the reader understand why these takeaways are significant
#
# For future stories that you create, ensure that you record similar details in any draft outline and think about how you would arrange those details in the story structure.
#
# >Note: If you plan to work with a group to create a story, you would review the outline with collaborators and colleagues to ensure that structural changes are made before you start assembling the story in ArcGIS StoryMaps.
#
# 4. When you are finished, close File Explorer and leave the outline document open.

# %% [markdown]
# ### **Create a story**

# %% [markdown]
# Now that you have completed the preparation phase, you can begin creating the story using the story builder.
#
# 1. Open a new private or incognito web browser window.
#
# >Note: It is recommended that you use a private or incognito web browser window to help prevent conflicts between your course ArcGIS account and the account that you use to sign in to the MOOC. For more information about private and incognito web browsers, see How to Enable Private Browsing on Any Web BrowserOpens in new window (https://www.howtogeek.com/269265/how-to-enable-private-browsing-on-any-web-browser/Opens in new window).
#
# 2. In the private or incognito web browser, go to https://storymaps.arcgis.comOpens in new window.
#
# 3. Sign in with your provided course ArcGIS account (with the username that ends with _sds).
#
# 4. Click Sign In.
#
# The Stories page appears. On the My Stories tab, stories that you create will be listed. If you have not created a story yet, this tab will be empty.
#
# 5. Under Create Your First Story, click Start A Story.
#
# >Note: If you have already created a story, click New Story and choose Start From Scratch.
#
# ![story_builder.JPG](attachment:226e1a87-7947-49f4-a675-dfaabb6f3562.JPG)
#
# The story builder opens with a blank story template. You have created a blank story that you will begin populating.

# %% [markdown]
# ### **Add text**

# %% [markdown]
# The blank story template is ready for you to add content. Using the outline that was provided, you will start building the story by using content blocks. Each title, paragraph, image, and media type is added to the story as a separate content block.
#
# In this step, you will add text to your story.
#
# 1. Review the StoryMapsOutline file again.
#
# This outline organizes the text into blocks of content and categorizes the text as a title, a heading, paragraph text, and so on. These categories align with the story elements that you will see later in this step. You will use this outline to copy and paste text into the story.
#
# 2. In the story builder, click Story Title and type `In the Shadow of a Volcano`.
#
# 3. Click Start With A Short Introduction Or Subtitle (Optional) and type the following text:
# `Around the world, volcanoes threaten nearly half a billion people. Scientists are working to better forecast when eruptions will occur`.
#
# 4. If your byline was not automatically added, click Add A Byline (Optional) and type Volcano Expedition Team to specify the author of the story.
#
# 5. At the top of the page, next to Draft, confirm that the story automatically saved.
#
# >ArcGIS StoryMaps automatically saves each edit to your story.
#
# 6. Under the byline, scroll down, if necessary, and then next to Tell Your Story, click the Add Content Block button ![image.png](attachment:aa9d3909-3049-4c6c-8fd5-1881423d00f3.png).
#
# ![add_content_block.JPG](attachment:eaea9db9-e579-4d2b-b8fe-83f89a3cd3b0.JPG)
#
# The block palette appears with different elements that you can use to add content to your story:
#
# - Text blocks like a paragraph, heading, or quote
# - Visual accents like a separator or a button
# - Media blocks like an image, video, map, or embed (for external web content)
# - Immersive blocks like a slideshow, sidecar, or map tour (full-screen blocks that provide a different interactive reading experience)
#
# You will begin with a text block.
#
# 7. In your story, from the block palette, choose Text.
#
# 8. Type the following text or paste the text from your StoryMapsOutline document:
#
# `In 2017, a volcanologist, a photographer, and a cartographer traveled to Guatemala on a National Geographic-funded expedition.
# Their goal was threefold: to conduct innovative research that could help shape volcanic eruption warning systems; to create educational materials that explain the risks of living in the vicinity of a volcano; and to better understand what is appealing enough about these locations for communities to remain, despite the risks.`
#
# These paragraphs serve as both an introduction to and a summary of your story. To emphasize this text, you will italicize it.
#
# 9. Highlight the first sentence, and then in the text editing toolbar, click the Italic button Italic.
#
# 10. Repeat this step for the following paragraph beginning with "Their goal..."
#
# The text that you added is now italicized.
#
# >Note: You can also use keyboard shortcuts like Ctrl+I for italics and Ctrl+B for bold.
#
# 11. Under the second paragraph, click the Add Content Block button ![image.png](attachment:61decc96-bb22-4535-a57f-d4857995df74.png) and choose Text.
#
# 12. Type the following text or paste the text from your StoryMapsOutline document:
# `There's nothing quite like the thrill of going into the field for research.`
#
# 13. Highlight the text, and then from the text editing toolbar, click the Paragraph down arrow and choose Heading 2.
#
# ![header2.JPG](attachment:7b9e8c67-e33c-4d4b-b719-138f0bd0346f.JPG)
#
# This text is your first heading. You have learned how to add text to your story. If you want to continue adding text to match the example story, continue with the instructions in the Optional section. Otherwise, continue to the Add Media step.
#
# To learn more about the other types of text that you can add to your story, go to ArcGIS StoryMaps Help: [Add narrative text](https://doc.arcgis.com/en/arcgis-storymaps/author-and-share/add-narrative-text.htm).
#
# ### Optional
#
# 1. On your keyboard, press Enter.
#
# Paragraph is the default element in the block palette, which means that you do not need to specify this element type before adding text to the story.
#
# 2. Type or paste the following text from your StoryMapsOutline document:
#
# `It's a kind of nervous excitement that just keeps building—through grant writing, planning, meticulously taking stock of the necessary gear, packing, hustling through the airport, and watching the ground race by below the plane. Then, finally, the arrival.
# I'm here—I've made it to Quetzaltenango, and the Santiaguito complex is waiting.
# During this expedition, we planned to summit Santa María Volcano and investigate the hazards from an active Guatemalan volcano, monitor those hazards using photogrammetry techniques, and educate the local public about those hazards through a multifaceted media campaign.
# Note: If you choose to type the text, you can add the accent to María or omit it.`
#
# Use the StoryMapsOutline document to copy and paste the remaining text as paragraphs and headings to match the example story.
#
# > Note: To match the example story, you may need to add paragraph breaks or remove spaces from the text that you copy and paste.

# %% [markdown]
# ### **Add media**

# %% [markdown]
# After adding text, you can add media, such as images and videos, to break up a long narrative and provide context to your story.
#
# In this step, you will add visual elements from your content inventory based on the outline. You will begin with the first image in the example story, which is an image of the volcano complex that the explorers visited.
#
# 1. Under the italicized introductory paragraphs, above the first heading, point to the left margin.
#
# > Note: If necessary, you can click the story title at the top of the page to automatically scroll to the top of the story.
#
# 2. Click the Add Content Block button that appears and choose Image.
#
# 3. In the Add An Image window, click Browse Your Files and browse to the ..\EsriTraining\StoryMaps\StoryMapsImages folder.
#
# 4. Find and select the `VolcanoPanorama` image and click Open.
#
# 5. Click Add.
#
# ![panorama.JPG](attachment:c9d34ccd-1865-49c5-a7db-7efef4ecbd46.JPG)
#
# The image is added to the story. Because this image is a panorama, you will increase the size so that the image looks like a banner.
#
# 6. Point to the volcano panorama image.
#
# 7. On the image editing toolbar, click the Large button ![image.png](attachment:65189433-8672-4c84-9aec-15a6cbda37f6.png).
#
# >Note: The list of available image sizes on the toolbar depends on the width of the image that you upload.
#
# ![banner.JPG](attachment:74c45f1a-dd66-4d73-9759-0a9cdc3cc2ce.JPG)
#
# The image stretches across the story.
#
# 8. Point to the volcano panorama image.
#
# 9. In the image editing toolbar, click the Options button ![image.png](attachment:e9ac86b5-41e7-45d4-9cac-813a8d8b5cad.png).
#
# The Image Options window appears. Here, you can add attribution and alternative text to the image. Attribution text allows you to give credit to the original content creator. Alternative text, or alt text, describes the image so that anyone using a screen reader (often used by the visually impaired) will be able to hear a description of the displayed image. After publishing the story, you can view the alt text by pointing to the image.
#
# 10. Under Alternative Text, type `Santiaguito Volcano Complex`, and then click Save.
#
# ![alternative_text.JPG](attachment:f7cf8f84-ecb8-48c7-a14e-60693889b18d.JPG)
#
# For the next image, you will include alternative text and a caption. Captions appear under the image and describe the image in relation to the surrounding text. You can also use the caption to provide a photo credit.
#
# 11. Beneath the text that you added as Heading 2, add an image.
#
# > Note: If you chose to add all the optional text from the Add Text step, add the image after the paragraph that begins with "During this expedition, we planned to summit . . ."
#
# 12. In the Add An Image window, browse to the ..\EsriTraining\StoryMaps\StoryMapsImages folder, and then add the Arrival image.
#
# 13. Add the following alternative text: `Scientist sitting next to three sets of photogrammetry equipment`.
#
# 14. Under the image, click Add A Caption (Optional) and type the following text:
# `Dr. Stephanie Grocke sets up and tests photogrammetry equipment before the expedition up Santa María Volcano. Photo: Gabby Salazar.`
#
# ![caption.JPG](attachment:b0747e33-6ad2-43e6-a0fb-41eedc743913.JPG)
#
#
# Notice how media is being used to visualize your story and emphasize the text.
#
# Adding media can be an iterative process where you modify text, graphics, and the order in which the content is presented. If you want to continue adding media to match the example story, continue with the instructions in the Optional section. Otherwise, continue to the Add An Immersive Block step.
#
# To learn more about the other media types that you can add to your story, go to ArcGIS StoryMaps Help: [Add media](https://doc.arcgis.com/en/arcgis-storymaps/author-and-share/add-media.htm).
#
# Next, you will create an immersive block. The immersive block will emphasize a set of graphics in your story and create a more interactive experience for the reader.
#
# ### Optional
# Use the same workflow from the preceding instructions to continue adding the following images and alternative text.
#
# > Note: You should complete adding the optional text from the Add Text step before you add these optional images.
#
# ![image_and_text.JPG](attachment:b0799b96-2122-41ab-a14c-bf61b9181d8e.JPG)
#
# You can refer to the example story, In the Shadow of a VolcanoOpens in new window, to guide you.

# %% [markdown]
# ### **Add an immersive block**

# %% [markdown]
# In addition to text and media, adding an immersive block provides an interactive experience for your audience. Different types of immersive blocks include slideshows, sidecars, and map tours.
#
# In this step, you will add a sidecar, which allows you to add multiple slides. Each slide will have its own stationary media panel and a scrolling narrative panel with content such as text, media, and maps. This sidecar will showcase images captured by Gabby Salazar with explanatory text.
#
# 1. At the end of your current story, click the Add Content Block button and, under Immersive, choose Sidecar.
#
# ![sidecar.JPG](attachment:26ee5858-a33e-4246-8800-9bafe997558d.JPG)
#
# > Note: If you chose to add all the optional text from the Add Text step, add the sidecar after the paragraph that begins with "Each time I travel to Quetzaltenango . . ."
#
# The Choose A Layout window appears. The sidecar immersive block provides three different layout options.
#
# ![sidecar_layout.JPG](attachment:25ead28b-bd1e-4899-913b-e2ab727d77fb.JPG)
#
# >Note: If you have not used a sidecar previously, you may see the What Is A Sidecar wizard. Review each page of the wizard, using the Next arrow to proceed to the following page. To close the wizard when you are finished, click Got It.
#
# 2. In the Choose A Layout window, confirm that Docked is selected, and then click Done.
#
# A sidecar with one slide is added to the story. The media panel is on the right, and the narrative panel is on the left.
#
# 3. In the media panel, click Add and choose Image Or Video.
#
# ![sidecar_add_image_or_video.JPG](attachment:43cc8bc1-983b-4146-bb73-95a1b88c4cd7.JPG)
#
# 4. In the Add An Image Or Video window, add the Coffee image.
#
# The image of raw coffee beans is added to the media panel. Next, you will add alternative text to the image and explanatory text to the narrative panel.
#
# 5. At the top of the image, click the Options button.
#
# 6. In the Image Options window, click the Properties tab.
#
# 7. Add the following alternative text: `Hands holding raw coffee beans`.
#
# 8. Click Save.
#
# 9. In the narrative panel, to the left of Continue Your Story, add the following text as Heading 2: `Agriculture around volcanoes thrives in the productive soil. Coffee grows particularly well around Santa María.`
#
# 10. Press Enter and type Photo: Gabby Salazar, leaving the photo credit in the default Paragraph style.
#
# ![coffee_beans.JPG](attachment:d6cec9e5-f898-4920-854c-0111166e6992.JPG)
#
# The explanatory text is added to the narrative panel, completing the slide.
#
# The sidecar is complete. You can scroll up and down in the story to preview the readers' experience as they transition to the immersive sidecar experience.
#
# If you want to add additional slides in the sidecar to match the example story, continue with the instructions in the Optional section. Otherwise, continue to the Create An Express Map step.
#
# To learn more about sidecars, go to ArcGIS StoryMaps Help: [Add sidecars](https://doc.arcgis.com/en/arcgis-storymaps/author-and-share/add-sidecars.htm).
#
# ### Optional
# You can add additional slides to this sidecar by using the sidecar panel at the bottom of the story builder.
#
# 1. In the bottom-right corner of the sidecar panel, click the New Slide button ![image.png](attachment:64ed3379-8c22-436f-8b9d-ca4b51b66230.png).
#
# A blank slide is added to the sidecar panel. You can use the sidecar panel to add or remove slides, adjust the transitions between slides, or remove the sidecar from your story entirely.
#
# 2. Use the same workflow from the preceding instructions to add the following slides.
#
# ![optional_added_media.JPG](attachment:84364ec3-a213-4719-b0dc-a3c4853707e1.JPG)
#
# If you would like to do so, add the remaining media and immersive blocks from the example story. If you decide to add the rest of the media and immersive blocks, do not add the map or scene as those will be added in later steps.

# %% [markdown]
# ### **Create an express map**

# %% [markdown]
# A benefit of using ArcGIS StoryMaps is the ability to tie narratives to locations. Another element that can be added to a story is an express map. An express map shows simple location information and allows you to use drawing and annotation tools to include information on a map. Express maps are made by the creator of the story during the authoring process, and they are stored as part of the story itself.
#
# In this step, you will create an express map of Quetzaltenango, Guatemala, which is the location where the story takes place.
#
# 1. At the beginning of the story, after the paragraph that begins with "In 2017, a volcanologist, a photographer, and a cartographer . . . ," click the Add Content Block button and choose Map.
#
# The map browser appears. You have the option to create an express map or add an existing map or scene from your organization or ArcGIS Living Atlas of the World. Because this story takes place in Quetzaltenango, Guatemala, you will create an express map that helps readers identify this location.
#
# 2. Click Start An Express Map.
#
# > Note: If you have already created an express map, click New Express Map. If you have not used express maps previously, you may see the Meet Express Maps wizard. Review each page of the wizard, using the Next arrow to proceed to the following page. To close the wizard when you are finished, click Got It.
#
#
# The map designer displays a gray map of the world. Above the map is a toolbar that you can use to draw features on the map. To the left of the map is a side panel that you can use to review the layers in your map, bookmarks, and map settings.
#
# You will use the toolbar to locate `Quetzaltenango, Guatemala`, which is the site of the expedition.
#
# 3. In the upper-right corner, in the Search By Location field, type Quetzaltenango, GTM and press Enter.
#
# > Note: Your pop-up and map labels may be slightly different.
#
# The map zooms to Quetzaltenango.
#
# 4. In the pop-up window, click Add To Map.
#
# ![add_to_map.JPG](attachment:d5fad154-8e22-477e-bbce-de31a1438265.JPG)
#
# A pin is added to the map. In the side panel, you can add an image and descriptive text for this point. This information will be displayed in a small pop-up window that the reader can open for more information.
#
# 5. In the side panel, click Add Image and select the Quetzaltenango image.
#
# > Note: The Quetzaltenango image file is in the StoryMapsImages folder.
#
# 6. Under the image, in the Description (Optional) field, type `According to the Instituto Nacional de Estadística Guatemala, the municipality of Quetzaltenango is home to approximately 180,706 people as of 2018.`
#
# ![map_image.JPG](attachment:5e4cd76b-050d-4ff9-ad25-00a0d661be94.JPG)
#
# 7. In the side panel, click Done.
#
# The side panel lists the newly named feature.
#
# 8. In the map, zoom out until you can see the entire country of Guatemala and some of its neighboring countries.
#
# > Note: You can use your mouse wheel or, in the bottom-right corner of the map, use the Zoom Out button Zoom Out.
#
# 9. Pan the map so that the point is positioned near the center of the map view, as shown in the following graphic.
#
# ![guatemala.JPG](attachment:9123ac7b-96af-40fe-9797-e1e662067b27.JPG)
#
# >Note: Your map view might look slightly different.
#
# The map is ready to place in the story. After adding the map to the story, you can adjust the size of the map, interact with the map, and preview pop-ups.
#
# 10. In the bottom-right corner, under the map, click Place Map.
#
# A map that shows the approximate location of the expedition is added to the story.
#
# 11. Point to the map.
#
# 12. In the image editing toolbar, click the Small button ![image.png](attachment:9e99dede-6dd6-48f5-acf4-ff8a7d4c40cf.png).
#
# ![map_small.JPG](attachment:8e21a6ce-6383-4f3b-a201-a867d146bba5.JPG)
#
# The map resizes to match the width of the story text. You have added a simple example of an express map that uses a point feature and a pop-up to provide geographical context to your story. You can also draw lines and areas and use annotation to complement the features on your map. To learn more about express maps, go to ArcGIS StoryMaps Help: [Add maps](https://doc.arcgis.com/en/arcgis-storymaps/author-and-share/add-maps.htm).

# %% [markdown]
# ### **Add a scene**

# %% [markdown]
# With ArcGIS StoryMaps, you can add web maps and web scenes to your story. Web maps are interactive maps that are hosted online and web scenes are interactive three-dimensional views of maps.
#
# There are various ways to add and configure maps and scenes in your story:
#
# - Add maps and scenes that you created using your course ArcGIS account.
# - Add maps and scenes from public ArcGIS content that you add as favorite content.
# - Add maps and scenes that were created by other members of your ArcGIS Online organization.
# - Add maps and scenes from ArcGIS Living Atlas of the World.
#
# In this step, you will add a preexisting 3D scene that shows the route that the explorers completed. This scene is shared publicly on ArcGIS Online. To add the scene to your map, you will need to select the item as a favorite so that you can access it from the My Favorites tab.
#
# 1. Open a new tab in your private or incognito web browser.
#
# 2. Go to the item page for the Santa Maria Volcano web scene [https://links.esri.com/3DWebScene](https://links.esri.com/3DWebScene).
#
# > Note: The complete URL to the item page is https://www.arcgis.com/home/item.html?id=48a2f65a673b4fa296b127afe6e49c8eOpens in new window.
#
# 3. Sign in to ArcGIS Online using your provided course ArcGIS account (your username that ends with _sds).
#
# 4. On the item page, under the thumbnail, click Add To Favorites.
#
# ![santa_maria_fav.JPG](attachment:fa89c14e-a217-45fb-aea6-df9766baee0a.JPG)
#
# The item was added to your list of favorite content. You can now add the scene to your story.
#
# 5. Close the web browser tab with the item page and return to the story builder.
#
# 6. In the story builder, scroll down past the sidecar.
#
# 7. At the end of your current story, click the Add Content Block button and choose Map.
#
# > Note: If you chose to add all the optional text from the Add Text step, add the map after the paragraph that begins with "At first light on November 12 . . ."
#
# 8. On the Add A Map page, click the My Favorites tab.
#
# ![add_map_myfav.JPG](attachment:dd759f79-aeb7-4791-b8e1-6df2a1ea9849.JPG)
#
# The My Favorites tab lists any ArcGIS Online content that you have marked as a favorite, including the scene that you just added.
#
# 9. Click Santa Maria Volcano.
#
# ![santa_maria_volcano.JPG](attachment:c9ebc20b-2ea5-48cf-9f37-e2a687c80e86.JPG)
#
# The scene displays in the map designer. The side panel lists the scene layers. Using the side panel, you can rename layers, turn off scene layers, and turn the scene legend on and off. Any edits that are made in the map designer will apply only to the scene that is added to the story.
#
# 10. In the bottom-right corner, under the scene, click Place Map.
#
# ![place_map.JPG](attachment:bc21718c-c44f-4528-8b72-a19d806b58a2.JPG)
#
# > Note: The scene may take a moment to appear before you can click Place Map.
#
# The scene is added to the story. You can zoom and pan this scene directly in the story.
#
# > Note: If you want to add a map or scene that was created in ArcGIS Pro, share the item as a web map or web scene to ArcGIS Online, and then add it to your story.
#
# For more information about sharing web maps, go to ArcGIS Pro Help: Share a web mapOpens in new window. For more information about sharing web scenes, go to ArcGIS Pro Help: [Share a web scene](https://pro.arcgis.com/en/pro-app/latest/help/sharing/overview/share-a-web-scene.htm).
#
# You created an initial draft of your story. Before publishing the story, you will review it.

# %% [markdown]
# ### **Choose a story design**

# %% [markdown]
# Some final steps of the creation phase are to apply a design that reflects the tone of your story and to review your story to ensure that the content is accurate. Choosing your story's design—its overall look and feel—is just as important as choosing the right content. You want to ensure that the story's visual cues (colors, typography, map symbology, and so on) match the tone of the narrative. For example, darker colors paired with formal fonts can indicate that the story is more serious.
#
# In this step, you will explore the design options and choose an appropriate theme and then preview your story.
#
# 1. At the top of the story builder, click Design.
#
# The story builder's Design panel appears, listing options for the cover layout and theme for your story.
#
# 2. In the Design panel, under Theme, choose `Obsidian` and scroll through the story.
#
# ![obsidian.JPG](attachment:b3da24c7-6819-4e6f-94a2-12d7c99a4afa.JPG)
#
# Themes change the overall design of the story, from color scheme to typography to the basemap and symbology of an express map. You can switch between themes to decide which one is most aligned with your story.
#
# 3. In the Design panel, under Theme, choose `Summit` and scroll through the story.
#
# ![summit.JPG](attachment:e8c2bf90-00d5-467a-ba55-aea779cc6110.JPG)
#
# You want to choose a theme that best matches the tone of your story and the story's visuals. This story is fairly light and uses images with shades of blue and green. Based on this information, `Summit `would be the more appropriate theme. Summit has a light theme, modern typography, and a minimalist look that helps communicate the excitement that the explorers felt while on the expedition.
#
# 4. After you finish reviewing the story, in the upper right of the Design panel, click the gray X.
#
# 5. At the top of the story builder, click Preview.
#
# >Note: If necessary, click Yes, Continue in the Preview Will Reset Undo History pop-up.
#
# Preview shows you how the story will appear for readers. In addition to reviewing the visual design choices like the theme you applied, you can use the preview to review the story for misspelled words, missing alternative text, continuity errors, and other changes that you might want to make before publishing.
#
# You can also preview the story in different modes. The full screen browser preview displays by default; however, you can also preview the story in tablet and smartphone views.
#
# 6. At the bottom right of the preview display, click the Preview On Tablet button ![image.png](attachment:c5c23f9d-f5fa-490c-ae9e-b979cf776a1a.png).
#
# ![tablet_view.JPG](attachment:1a3a9fd9-b0b1-4757-9ef6-fa5fb5d85677.JPG)
#
# The story appears within a tablet view. You can scroll through the story to preview how each of the story elements would appear on this device - you can even rotate the screen between portrait and landscape.
#
# 7. When you are finished exploring, click the phone preview button.
#
# ![phone_preview.JPG](attachment:1e596f0b-230b-4004-aba6-e5cf3afc1bac.JPG)
#
# The story appears within a mobole phone view - you can even rotate the screen between portrait and landscape.
#
# > Note: It is recommended that you review your story after taking a break from authoring so that you have a fresh perspective. It would also be a good time to ask others for their feedback and suggestions.
#
# 8. At the bottom of the preview display, click the Close Preview button ![image.png](attachment:c1544c54-4ab5-4387-b0a3-81208eda3275.png).
#
# 9. If necessary, make any remaining changes to the story.
#
# You have explored design options for your story, and you previewed the various display options that are available to readers. Next, you will publish your story for the public.

# %% [markdown]
# ### **Publish a story for sharing**

# %% [markdown]
# After final design touches are added and the story is reviewed, it is ready to be shared with others.
#
# In this step, you will publish your version of In the Shadow of a Volcano.
#
# 1. At the top of the story builder, click Publish.
#
# > Note: You can only publish the story from the Draft view.
#
# You can share this story with other members of your ArcGIS Online organization or with the public. Sharing this story publicly means that anyone can find and view the story. You can also configure the story card to customize the details, or social metadata, that are displayed when the story appears on social media sites and in search engine results.
#
# 2. Under Share, click the down arrow and choose Everyone (Public).
#
# 3. At the top right of the page, click Publish.
#
# The story is now available for others to read. You can reopen your story in the story builder and continue making edits or updates without affecting the shared story. If you change the story, republish it by clicking the More Actions button More Actions at the top of the page and choosing Edit Story. The More Actions button enables you to discard changes, change the story settings, or unpublish the story.
#
# In this exercise, you learned how to use the story builder to create a story. You also identified the characteristics of an effective story and learned how to implement these characteristics using media types, maps, and even the overall design of the story.
#
# 4. If you would like to add an interactive element to your story, proceed to the optional stretch goal; otherwise, close the private or incognito web browser window.

# %% [markdown]
# ### **Stretch goal (Optional)**

# %% [markdown]
# f you would like to add an interactive element to your story, you can continue with this stretch goal to add a time-enabled web map to your story using the time widget. An interactive map that shows events or changes over time can be a powerful storytelling tool. The time widget reads the time settings from the web map and enables readers to play and pause the map's time animation.
#
# You will create a time-enabled map in ArcGIS Pro from a CSV file and share it as a web map to ArcGIS Online so that you can add it to your story. The map that you create will show volcanic eruptions that took place globally from 2001 to 2021. It should be symbolized based on the VEI, or Volcanic Explosivity Index. Alternatively, you can add a time-enabled web map to your story that has been created for you using this link: https://links.esri.com/VolcanoEruptionsOpens in new window (https://www.arcgis.com/home/item.html?id=311b1e2e169a4444bb48eaa552aff5e8Opens in new window). You will need to sign in to your course ArcGIS account to add the web map and select it as a favorite so that you can access it from the My Favorites tab.
#
# The tasks for this stretch goal have been grouped to more clearly define the workflow that you are completing.
#
# > Note: If you need assistance completing the following tasks, refer to these resources:
#
# - ArcGIS Pro Help: Add x,y coordinate data as a layerOpens in new window
# - ArcGIS Pro Help: Configure time slider settingsOpens in new window
# - ArcGIS Pro Help: Share a web mapOpens in new window
# - ArcGIS Blog: Animate time-enabled maps with the time widgetOpens in new window
#
# 1. Create a time-enabled web map in ArcGIS Pro.
#
# - Start ArcGIS Pro and open a blank map template.
# - Add the VolcanoEruptions20Years table (VolcanoEruptions20Years.csv) to the map\
# *The VolcanoEruptions20Years.csv file is located in the StoryMaps data folder*
# - Create point locations for the volcanoes.
# - Symbolize the points using graduated symbols based on the VEI field and, if you would like, change the basemap.
# - In the layer's properties, set the layer time and adjust the time span to be one year.
# - Save and share the map as a web map to ArcGIS Online.
#
# 2. Add the time-enabled map to the sidecar.
#
# - Return to editing your story.
# - Add a new slide to the sidecar immersive block that you initially created.
# - Add the time-enabled map.
# - Add text in the narrative panel that provides context for the map.
# - Republish your story.
